# %%
import pandas as pd

books = pd.read_csv('books_cleaned.csv')

# %%
#Checking the distribution of the categories
books['categories'].value_counts()
# Out:
# categories
# Fiction                      2523
# Juvenile Fiction              534
# Biography & Autobiography     391
# History                       258
# Literary Criticism            164
#                              ...
# Actresses                       1
# Apartments                      1
# Books                           1
# Antislavery movements           1
# Indic fiction (English)         1
# Name: count, Length: 531, dtype: int64

# %%
books[books['categories'] == 'Juvenile Fiction'].head()
# Out:
#             isbn13      isbn10                           title  \
# 35   9780006646006  000664600X              Ocean Star Express
# 96   9780020442608  0020442602  The voyage of the Dawn Treader
# 106  9780030420566  0030420563              Rest, Rabbit, Rest
# 107  9780030547744  0030547741        Where the Red Fern Grows
# 108  9780060000141  0060000147                  Poppy's Return
#
#                               authors        categories  \
# 35           Mark Haddon;Peter Sutton  Juvenile Fiction
# 96                Clive Staples Lewis  Juvenile Fiction
# 106  Jacquelyn Reinach;Richard Hefter  Juvenile Fiction
# 107                      Wilson Rawls  Juvenile Fiction
# 108                               Avi  Juvenile Fiction
#
#                                              thumbnail  \
# 35   http://books.google.com/books/content?id=I2QZA...
# 96   http://books.google.com/books/content?id=fDD3C...
# 106  http://books.google.com/books/content?id=8-40_...
# 107  http://books.google.com/books/content?id=IHpRw...
# 108  http://books.google.com/books/content?id=XbcMJ...
#
#                                            description  published_year  \
# 35   Joe and his parents are enjoying a summer holi...          2002.0
# 96   The "Dawn Treader" is the first ship Narnia ha...          1970.0
# 106  Rabbit's schedule keeps him so busy his friend...          1978.0
# 107  A young boy living in the Ozarks achieves his ...          2000.0
# 108  There's trouble at Gray House, the girlhood ho...          2006.0
#
#      average_rating  num_pages  ratings_count  \
# 35             3.50       32.0            1.0
# 96             4.09      216.0         2869.0
# 106            4.01       32.0           88.0
# 107            4.37      288.0           95.0
# 108            3.99      256.0         1086.0
#
#                                     tagged_description
# 35   9780006646006 Joe and his parents are enjoying...
# 96   9780020442608 The "Dawn Treader" is the first ...
# 106  9780030420566 Rabbit's schedule keeps him so b...
# 107  9780030547744 A young boy living in the Ozarks...
# 108  9780060000141 There's trouble at Gray House, t...

# %%
books[books['categories'] == 'Juvenile Nonfiction'].head()
# Out:
#             isbn13      isbn10                          title  \
# 133  9780060277406  0060277408     The Secret Garden Cookbook
# 134  9780060278427  0060278420                  Laura's Album
# 149  9780060513092  0060513098                     Falling Up
# 261  9780060782139  0060782137    Time For Kids: Butterflies!
# 301  9780060882600  0060882603  The Annotated Charlotte's Web
#
#                       authors           categories  \
# 133                Amy Cotler  Juvenile Nonfiction
# 134          William Anderson  Juvenile Nonfiction
# 149          Shel Silverstein  Juvenile Nonfiction
# 261  Editors of TIME For Kids  Juvenile Nonfiction
# 301               E. B. White  Juvenile Nonfiction
#
#                                              thumbnail  \
# 133  http://books.google.com/books/content?id=c7E_H...
# 134  http://books.google.com/books/content?id=_zTkq...
# 149                                                NaN
# 261  http://books.google.com/books/content?id=OdZxn...
# 301  http://books.google.com/books/content?id=vaYYH...
#
#                                            description  published_year  \
# 133  Frances Hodgson Burnett's The Secret Garden de...          1999.0
# 134  Though best known as the author of the Little ...          1998.0
# 149  A collection of humorous poems and drawings. C...          2002.0
# 261  Butterflies There are 20,000 different kinds o...          2006.0
# 301  Charlotte's Web, one of America's best-loved c...          2006.0
#
#      average_rating  num_pages  ratings_count  \
# 133            4.28      128.0          142.0
# 134            4.30       80.0          713.0
# 149            4.34      178.0       114058.0
# 261            4.00       32.0           20.0
# 301            4.16      320.0           41.0
#
#                                     tagged_description
# 133  9780060277406 Frances Hodgson Burnett's The Se...
# 134  9780060278427 Though best known as the author ...
# 149  9780060513092 A collection of humorous poems a...
# 261  9780060782139 Butterflies There are 20,000 dif...
# 301  9780060882600 Charlotte's Web, one of America'...

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}

books["simple_categories"] = books["categories"].map(category_mapping)
books["simple_categories"].value_counts()
# Out:
# simple_categories
# Fiction                  2876
# Nonfiction               1172
# Children's Fiction        534
# Children's Nonfiction     114
# Name: count, dtype: int64

# %%
from transformers import pipeline

fiction_categories = ["Fiction", "Nonfiction"]

pipe = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device='mps')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       1 from transformers import pipeline
#       3 fiction_categories = ["Fiction", "Nonfiction"]
# ----> 5 pipe = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device='mps')
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/pipelines/__init__.py:1027, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1025 if isinstance(model, str) or framework is None:
#    1026     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1027     framework, model = infer_framework_load_model(
#    1028         adapter_path if adapter_path is not None else model,
#    1029         model_classes=model_classes,
#    1030         config=config,
#    1031         framework=framework,
#    1032         task=task,
#    1033         **hub_kwargs,
#    1034         **model_kwargs,
#    1035     )
#    1037 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1039 # Check which preprocessing classes the pipeline uses
#    1040 # None values indicate optional classes that the pipeline can run without, we don't raise errors if loading fails
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/pipelines/base.py:293, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     287     logger.warning(
#     288         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     289         "Trying to load the model with Tensorflow."
#     290     )
#     292 try:
# --> 293     model = model_class.from_pretrained(model, **kwargs)
#     294     if hasattr(model, "eval"):
#     295         model = model.eval()
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/modeling_utils.py:277, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     275 old_dtype = torch.get_default_dtype()
#     276 try:
# --> 277     return func(*args, **kwargs)
#     278 finally:
#     279     torch.set_default_dtype(old_dtype)
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/modeling_utils.py:4900, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4890 if (
#    4891     gguf_file
#    4892     and device_map is not None
#    4893     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4894 ):
#    4895     raise RuntimeError(
#    4896         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4897         "loaded from GGUF files."
#    4898     )
# -> 4900 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4901     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4902     subfolder=subfolder,
#    4903     variant=variant,
#    4904     gguf_file=gguf_file,
#    4905     from_tf=from_tf,
#    4906     from_flax=from_flax,
#    4907     use_safetensors=use_safetensors,
#    4908     cache_dir=cache_dir,
#    4909     force_download=force_download,
#    4910     proxies=proxies,
#    4911     local_files_only=local_files_only,
#    4912     token=token,
#    4913     user_agent=user_agent,
#    4914     revision=revision,
#    4915     commit_hash=commit_hash,
#    4916     is_remote_code=cls._auto_class is not None,
#    4917     transformers_explicit_filename=transformers_explicit_filename,
#    4918 )
#    4920 is_sharded = sharded_metadata is not None
#    4921 is_quantized = hf_quantizer is not None
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/modeling_utils.py:1037, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1022 try:
#    1023     # Load from URL or cache if already cached
#    1024     cached_file_kwargs = {
#    1025         "cache_dir": cache_dir,
#    1026         "force_download": force_download,
#    (...)   1035         "_commit_hash": commit_hash,
#    1036     }
# -> 1037     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    1039     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    1040     # result when internet is up, the repo and revision exist, but the file does not.
#    1041     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    1042         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)    320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 try:
#     477     if len(full_filenames) == 1:
#     478         # This is slightly better for only 1 file
# --> 479         hf_hub_download(
#     480             path_or_repo_id,
#     481             filenames[0],
#     482             subfolder=None if len(subfolder) == 0 else subfolder,
#     483             repo_type=repo_type,
#     484             revision=revision,
#     485             cache_dir=cache_dir,
#     486             user_agent=user_agent,
#     487             force_download=force_download,
#     488             proxies=proxies,
#     489             resume_download=resume_download,
#     490             token=token,
#     491             local_files_only=local_files_only,
#     492         )
#     493     else:
#     494         snapshot_download(
#     495             path_or_repo_id,
#     496             allow_patterns=full_filenames,
#    (...)    505             local_files_only=local_files_only,
#     506         )
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/huggingface_hub/file_download.py:1010, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     990     return _hf_hub_download_to_local_dir(
#     991         # Destination
#     992         local_dir=local_dir,
#    (...)   1007         local_files_only=local_files_only,
#    1008     )
#    1009 else:
# -> 1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    1013         # File info
#    1014         repo_id=repo_id,
#    1015         filename=filename,
#    1016         repo_type=repo_type,
#    1017         revision=revision,
#    1018         # HTTP info
#    1019         endpoint=endpoint,
#    1020         etag_timeout=etag_timeout,
#    1021         headers=hf_headers,
#    1022         proxies=proxies,
#    1023         token=token,
#    1024         # Additional options
#    1025         local_files_only=local_files_only,
#    1026         force_download=force_download,
#    1027     )
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/huggingface_hub/file_download.py:1171, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1168 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1170 with WeakFileLock(lock_path):
# -> 1171     _download_to_tmp_and_move(
#    1172         incomplete_path=Path(blob_path + ".incomplete"),
#    1173         destination_path=Path(blob_path),
#    1174         url_to_download=url_to_download,
#    1175         proxies=proxies,
#    1176         headers=headers,
#    1177         expected_size=expected_size,
#    1178         filename=filename,
#    1179         force_download=force_download,
#    1180         etag=etag,
#    1181         xet_file_data=xet_file_data,
#    1182     )
#    1183     if not os.path.exists(pointer_path):
#    1184         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/huggingface_hub/file_download.py:1723, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1721 if xet_file_data is not None and is_xet_available():
#    1722     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1723     xet_get(
#    1724         incomplete_path=incomplete_path,
#    1725         xet_file_data=xet_file_data,
#    1726         headers=headers,
#    1727         expected_size=expected_size,
#    1728         displayed_filename=filename,
#    1729     )
#    1730 else:
#    1731     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/huggingface_hub/file_download.py:615, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     612 if len(displayed_filename) > 40:
#     613     displayed_filename = f"{displayed_filename[:40]}(…)"
# --> 615 progress_cm = _get_progress_bar_context(
#     616     desc=displayed_filename,
#     617     log_level=logger.getEffectiveLevel(),
#     618     total=expected_size,
#     619     initial=0,
#     620     name="huggingface_hub.xet_get",
#     621     _tqdm_bar=_tqdm_bar,
#     622 )
#     624 with progress_cm as progress:
#     626     def progress_updater(progress_bytes: float):
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/huggingface_hub/utils/tqdm.py:299, in _get_progress_bar_context(desc, log_level, total, initial, unit, unit_scale, name, _tqdm_bar)
#     294     return nullcontext(_tqdm_bar)
#     295     # ^ `contextlib.nullcontext` mimics a context manager that does nothing
#     296     #   Makes it easier to use the same code path for both cases but in the later
#     297     #   case, the progress bar is not closed when exiting the context manager.
# --> 299 return tqdm(
#     300     unit=unit,
#     301     unit_scale=unit_scale,
#     302     total=total,
#     303     initial=initial,
#     304     desc=desc,
#     305     disable=is_tqdm_disabled(log_level=log_level),
#     306     name=name,
#     307 )
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/tqdm/std.py:665, in tqdm.__new__(cls, *_, **__)
#     663 def __new__(cls, *_, **__):
#     664     instance = object.__new__(cls)
# --> 665     with cls.get_lock():  # also constructs lock if non-existent
#     666         cls._instances.add(instance)
#     667         # create monitoring thread
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/tqdm/std.py:111, in TqdmDefaultWriteLock.__enter__(self)
#     110 def __enter__(self):
# --> 111     self.acquire()
#
# File ~/Desktop/Developer/AI Engineering/Semantic Book Recommender/recommender/lib/python3.11/site-packages/tqdm/std.py:104, in TqdmDefaultWriteLock.acquire(self, *a, **k)
#     102 def acquire(self, *a, **k):
#     103     for lock in self.locks:
# --> 104         lock.acquire(*a, **k)
#
# KeyboardInterrupt:
